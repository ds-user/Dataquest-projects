# %% [markdown]
# # Cleaning Up Data from eBay Kleinanzeige
#  - This data is from eBay Kleinanzeigen - a classified section of the German eBay website
#  - In this notebook, the program will clean the data and analyze the data

# %% [markdown]
# ## Part I - Introduction

# %%
import pandas as pd
import numpy as np
autos=pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# ### Observations
#  - Mix of objects and integer columns
#  - Not all columns have 5,000 non-null values meaning some are nulls

# %% [markdown]
# ## Part II - Cleaning Column Names

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
copy_autos=autos.copy()
print(copy_autos.head())
type(copy_autos)
copy_autos.columns
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
copy_autos.rename(columns = {'yearOfRegistration':'registration_year',
                                       'monthOfRegistration':'registration_month',
                                       'notRepairedDamage':'unrepaired_damage',
                                       'dateCreated':'ad_created',
                                       'dateCrawled':'date_crawled',
                                       'offerType':'offer_type',
                                       'abtest':'ab_test',
                                       'vehicleType':'vehicle_type',
                                       'fuelType':'fuel_type',
                                       'nrOfPictures':'nr_pf_pictures',
                                       'postalCode':'postal_code',
                                       'lastSeen':'last_seen'},inplace=True)

# %%
copy_autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
#        'vehicle_type', 'registration_year', 'gearbox', 'powerPS', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_pf_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.columns=copy_autos.columns
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  powerPS   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# - Changes were made in column names from CamelCase to snake_case so it would be easier to replace spaces with underscores and for an easier read

# %% [markdown]
# ## Part III Initial Exploration and Cleaning

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-04-04 16:40:33  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %% [markdown]
# - Columns with 2 unique options: seller, offer_type, abtest, gearbox, unrepaired_damage
# - Columns that need more investigation: ab_test to see what a/b test was conducted and thos with only 2 unique options to investigate whether keeping those columns is essential to this investigation
# - columns that store numeric data as text:  price, odometer (dates and timestamps are also not numeric, but in date/time formated i.e. date_crawled, ad_created and last_seen)

# %%
autos['price']=autos['price'].str.replace('$','').str.replace(',','')
autos['odometer']=autos['odometer'].str.replace('km','').str.replace(',','')
autos.head()
autos['price']=autos['price'].astype(int)
autos['odometer']=autos['odometer'].astype(int)
print(autos['price'].dtype)
print(autos['odometer'].dtype)
autos.rename(columns={'odometer':'odometer_km'},inplace=True)
# Out:
# int64
# int64

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  powerPS   model  odometer_km  registration_month fuel_type  \
# ...

# %% [markdown]
# ## Part IV - Exploring the Odometer and Price Columns

# %%
print('\n number of values ') 
print(autos.shape[0])
print('\n number of unique values ') 
print(autos['odometer_km'].unique().shape)
print('\n the unique values ')
print(autos['odometer_km'].unique())
print('\n min,max,median,mean ')
print(autos['odometer_km'].describe())
print('\n descending order of top 50 ')
print(autos['odometer_km'].head(50).value_counts().sort_index(ascending=False))
# Out:
#  number of values
# 50000
#
#  number of unique values
# (13,)
#
#  the unique values
# [150000  70000  50000  80000  10000  30000 125000  90000  20000  60000
#    5000 100000  40000]
#
#  min,max,median,mean
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64
#
#  descending order of top 50
# 150000    38
# 125000     2
# 90000      1
# 80000      1
# 70000      2
# 60000      2
# 50000      1
# 30000      1
# 20000      1
# 10000      1
# Name: odometer_km, dtype: int64

# %% [markdown]
# - The odometer values seem to be reasonable - of 5,000 values there are only 13 unique values that are multiples of 1,000 which lead to the belief that the odometer classification are ranges as oppose to absolute values
# - The values range from 5,000 km to 150,000 km which is reasonable
# - There seems to be no outliers in this dataset

# %%
print('\n number of values ') 
print(autos.shape[0])
print('\n number of unique values ') 
print(autos['price'].unique().shape)
print('\n the unique values ')
print(autos['price'].unique())
print('\n min,max,median,mean ')
print(autos['price'].describe())
print('\n descending order of top 50 ')
print(autos['price'].head(50).value_counts().sort_index(ascending=False))
# Out:
#  number of values
# 50000
#
#  number of unique values
# (2357,)
#
#  the unique values
# [ 5000  8500  8990 ...   385 22200 16995]
#
#  min,max,median,mean
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64
#
#  descending order of top 50
# 56000    1
# 48500    1
# 41500    1
# 25450    1
# 18900    1
# 13800    1
# 11900    1
# 11500    1
# 9000     1
# 8990     1
# 8500     1
# 7999     1
# 7900     1
# 7500     1
# 5500     1
# 5299     1
# 5250     1
# 5000     1
# 4999     1
# 4800     1
# 4350     1
# 4150     1
# 3999     1
# 3500     2
# 3499     1
# 3200     1
# 2850     2
# 2600     1
# 1990     1
# 1450     1
# 1350     2
# 1200     1
# 1099     1
# 1000     1
# 999      1
# 900      1
# 777      1
# 590      1
# 350      3
# 300      2
# 250      1
# 90       1
# 80       1
# 0        1
# ...

# %% [markdown]
# - Of the 50,000 values in the price column there are 2,367 unique values meaning that either prices appear multiple times or there are some prices that repeat very often
# - Looking at the sorted value count of the first 50 values, it seems that it is the former in that prices appear a multiple times
# - The describe function gives the min and max which are quite suspicious as they are 0 and 1 million respectively. A further investigation needs to be conducted for this dataset
# - One way to do so is to look at all the values below 2,000 and above 100,000
# - **Examinated values below 2,000 and there were almost 20,000 therefore going to narrow it down to values below 500 - there were 5,000 values below 500, now going to look at below 100 - these values seem appropriate as they either have an old registration year or have a high odometer value or both - now going to examine under 50 which has about 1,600 values mostly 0's and 1's - going to see how many are below 1 - a little over 1400 values - going to eliminate values below 1 as starting selling a car for no money seems suspicious**
# - **Examinated values above 100,000 - 53 values - some seem reasonable as they are expensive brands (i.e. Porsche) going to raise the value to 1,000,000 - 11 values - some models like the Ferrari's seem reasonable and some do not - time to research each car to see if the prices are reasonable - after researching some of the most expensive cars sold on auction as well as the models of the cars that make up these eleven values it seemed reasonable that values below 10,000 would be included as some prices such as 99,999,999 and 12,345,678 seemed to be suspicious from the sequencing of the numbers**

# %%
examlow=autos[autos['price']<1]
print(examlow.shape[0])
examlow
# Out:
# 1421
#               date_crawled                                               name  \
# 27     2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
# 71     2016-03-28 19:39:35  Suche_Opel_Astra_F__Corsa_oder_Kadett_E_mit_Re...
# 80     2016-03-09 15:57:57  Nissan_Primera_Hatchback_1_6_16v_73_Kw___99Ps_...
# 87     2016-03-29 23:37:22                      Bmw_520_e39_zum_ausschlachten
# 99     2016-04-05 09:48:54                    Peugeot_207_CC___Cabrio_Bj_2011
# 118    2016-03-12 05:03:00  VW_Sharan_V6_204_PS_Karosse_Rohkarosse_mit_Pap...
# 146    2016-03-22 23:59:28                                    Ford_Fiesta_rot
# 167    2016-04-02 19:43:45  Suche_VW_Multivan_Innenausstattung_Set_oder_TE...
# 180    2016-03-19 10:50:25                                       Zu_verkaufen
# 226    2016-03-25 23:52:12                      Porsche_911_S_Targa__67er_SWB
# 234    2016-03-05 16:56:22                                   Fiat_Punto_Sport
# ...

# %%
examhigh=autos[autos['price']>1000000]
print(examhigh.shape[0])
print(examhigh['price'].value_counts().sort_index(ascending=False))
examhigh
# Out:
# 11
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# Name: price, dtype: int64
#               date_crawled                                               name  \
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# ...

# %%
autos[autos['price'].between(1,10000000)]
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %% [markdown]
# ## Part V - Exploring the Date Columns

# %%
autos[['date_crawled','ad_created','last_seen']][:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
#after value_counts can do .sort_index(ascending=False) , .sort_index() , .sort_values(ascending=True) and .sort_values()
#.shape[0] = 34
#.sum() = 1 to see if there it is out of 100%
# Out:
# 2016-03-05    0.02538
# 2016-03-06    0.01394
# 2016-03-07    0.03596
# 2016-03-08    0.03330
# 2016-03-09    0.03322
# 2016-03-10    0.03212
# 2016-03-11    0.03248
# 2016-03-12    0.03678
# 2016-03-13    0.01556
# 2016-03-14    0.03662
# 2016-03-15    0.03398
# 2016-03-16    0.02950
# 2016-03-17    0.03152
# 2016-03-18    0.01306
# 2016-03-19    0.03490
# 2016-03-20    0.03782
# 2016-03-21    0.03752
# 2016-03-22    0.03294
# 2016-03-23    0.03238
# 2016-03-24    0.02910
# 2016-03-25    0.03174
# 2016-03-26    0.03248
# 2016-03-27    0.03104
# 2016-03-28    0.03484
# 2016-03-29    0.03418
# 2016-03-30    0.03362
# 2016-03-31    0.03192
# 2016-04-01    0.03380
# 2016-04-02    0.03540
# 2016-04-03    0.03868
# 2016-04-04    0.03652
# 2016-04-05    0.01310
# 2016-04-06    0.00318
# 2016-04-07    0.00142
# Name: date_crawled, dtype: float64

# %% [markdown]
# - first crawled meaning: 'This is the date that the link was first located and indexed within the Fresh or Historic Indexes.'
# - crawled meaning: 'A web crawler is an internet bot that systematically browses world wide web for the purpose of extracting useful information'
# - All date crawled are daily from March 5th to April 7th of 2016
# - No date's frequency is above 3.9% and there are 34 dates that make up the distribution
# - It appears that the frequencies are around the same range as more than half of the values are 3-4%

# %%
autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_values(ascending=False)
#after value_counts can do .sort_index(ascending=False) , .sort_index() , .sort_values(ascending=True) and .sort_values()
#.shape[0] = 34
#.sum() = 1 to see if there it is out of 100%
# Out:
# 2016-04-03    0.03892
# 2016-03-20    0.03786
# 2016-03-21    0.03772
# 2016-04-04    0.03688
# 2016-03-12    0.03662
# 2016-03-14    0.03522
# 2016-04-02    0.03508
# 2016-03-28    0.03496
# 2016-03-07    0.03474
# 2016-03-29    0.03414
# 2016-03-19    0.03384
# 2016-04-01    0.03380
# 2016-03-15    0.03374
# 2016-03-30    0.03344
# 2016-03-08    0.03334
# 2016-03-09    0.03324
# 2016-03-22    0.03280
# 2016-03-11    0.03278
# 2016-03-26    0.03256
# 2016-03-23    0.03218
# 2016-03-31    0.03192
# 2016-03-25    0.03188
# 2016-03-10    0.03186
# 2016-03-17    0.03120
# 2016-03-27    0.03090
# 2016-03-16    0.03000
# 2016-03-24    0.02908
# 2016-03-05    0.02304
# 2016-03-13    0.01692
# 2016-03-06    0.01512
#                ...
# 2016-02-21    0.00006
# 2016-02-26    0.00004
# 2016-02-14    0.00004
# 2016-01-10    0.00004
# 2016-02-05    0.00004
# 2016-02-18    0.00004
# 2016-02-20    0.00004
# 2016-02-02    0.00004
# 2016-02-09    0.00004
# 2016-02-24    0.00004
# ...

# %% [markdown]
# - The dates the ads were created range 76 dates from June 2015 to April of 2016
# - The frequency of the dates are from 0.002 to 3.892% thus 3 orders of magnitude
# - Most of the ads were created in March and April of 2016

# %%
autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
#after value_counts can do .sort_index(ascending=False) , .sort_index() , .sort_values(ascending=True) and .sort_values()
#.shape[0] = 34
#.sum() = 1 to see if there it is out of 100%
# Out:
# 2016-03-05    0.00108
# 2016-03-06    0.00442
# 2016-03-07    0.00536
# 2016-03-08    0.00760
# 2016-03-09    0.00986
# 2016-03-10    0.01076
# 2016-03-11    0.01252
# 2016-03-12    0.02382
# 2016-03-13    0.00898
# 2016-03-14    0.01280
# 2016-03-15    0.01588
# 2016-03-16    0.01644
# 2016-03-17    0.02792
# 2016-03-18    0.00742
# 2016-03-19    0.01574
# 2016-03-20    0.02070
# 2016-03-21    0.02074
# 2016-03-22    0.02158
# 2016-03-23    0.01858
# 2016-03-24    0.01956
# 2016-03-25    0.01920
# 2016-03-26    0.01696
# 2016-03-27    0.01602
# 2016-03-28    0.02086
# 2016-03-29    0.02234
# 2016-03-30    0.02484
# 2016-03-31    0.02384
# 2016-04-01    0.02310
# 2016-04-02    0.02490
# 2016-04-03    0.02536
# 2016-04-04    0.02462
# 2016-04-05    0.12428
# 2016-04-06    0.22100
# 2016-04-07    0.13092
# Name: last_seen, dtype: float64

# %% [markdown]
# - All last seen are daily from March 5th to April 7th of 2016 as well
# - The first three dates make up the lowest date frequencies and the last three dates make up the highest date frequencies
# - The percentage range is wide: 0.11% to 22.10%

# %%
autos['registration_year'].describe()
# Out:
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# - The mean value is 2005 which is reasonable, it makes sense that in 2016 users are selling their car on ebay that is on average ~10 years old
# - The standard deviation at 105 is high, which means that the registration year highly deviates from the mean 2005.
# - The minimum amd maximum are unreasonable as in 1000 cars did not exist and 9999 is in the future for this dataset

# %% [markdown]
# ## Part VI - Dealing with Incorrect Registration Year Data

# %% [markdown]
# - Realistically, we would check the year the ad was created and make it so that the registration year is not higher than that, however in this case, because all the ads were created in 2015-2016, 2016 will be the upper limit of the registration years included
# - After some research, it appears that the earliest registration date was 1903 so that will be ther lower limit of the registration years included

# %%
# Calculate distribution of values
autos['registration_year'].value_counts(normalize=True)
# Out:
# 2000    0.06708
# 2005    0.06030
# 1999    0.06000
# 2004    0.05474
# 2003    0.05454
# 2006    0.05416
# 2001    0.05406
# 2002    0.05066
# 1998    0.04906
# 2007    0.04608
# 2008    0.04462
# 2009    0.04196
# 1997    0.04056
# 2011    0.03268
# 2010    0.03194
# 2017    0.02906
# 1996    0.02888
# 2012    0.02646
# 2016    0.02632
# 1995    0.02626
# 2013    0.01612
# 2014    0.01332
# 1994    0.01320
# 2018    0.00984
# 1993    0.00890
# 2015    0.00798
# 1990    0.00790
# 1992    0.00782
# 1991    0.00712
# 1989    0.00362
#          ...
# 1950    0.00006
# 1955    0.00004
# 9000    0.00004
# 1954    0.00004
# 1800    0.00004
# 1957    0.00004
# 1941    0.00004
# 1951    0.00004
# 1934    0.00004
# 4100    0.00002
# 4800    0.00002
# 1953    0.00002
# 1111    0.00002
# 1927    0.00002
# 6200    0.00002
# 4500    0.00002
# 1943    0.00002
# 5911    0.00002
# 1939    0.00002
# 1938    0.00002
# 2800    0.00002
# 8888    0.00002
# 1000    0.00002
# 1500    0.00002
# ...

# %%
# Percentage of car listings that fall outside the 1900 to 2016
# ~ = NOT
(~autos['registration_year'].between(1903,2016)).sum()/autos.shape[0]*100
# Out:
# 3.9440000000000004

# %%
# delete values that are not between 1903 and 2016
autos=autos[autos['registration_year'].between(1903,2016)]
autos.shape
# Out:
# (48028, 20)

# %%
# Recalculate distribution of remaining values
autos['registration_year'].value_counts(normalize=True)
# Out:
# 2000    0.069834
# 2005    0.062776
# 1999    0.062464
# 2004    0.056988
# 2003    0.056779
# 2006    0.056384
# 2001    0.056280
# 2002    0.052740
# 1998    0.051074
# 2007    0.047972
# 2008    0.046452
# 2009    0.043683
# 1997    0.042225
# 2011    0.034022
# 2010    0.033251
# 1996    0.030066
# 2012    0.027546
# 2016    0.027401
# 1995    0.027338
# 2013    0.016782
# 2014    0.013867
# 1994    0.013742
# 1993    0.009265
# 2015    0.008308
# 1990    0.008224
# 1992    0.008141
# 1991    0.007412
# 1989    0.003769
# 1988    0.002957
# 1985    0.002186
#           ...
# 1966    0.000458
# 1977    0.000458
# 1975    0.000396
# 1969    0.000396
# 1965    0.000354
# 1964    0.000250
# 1910    0.000187
# 1963    0.000187
# 1959    0.000146
# 1961    0.000125
# 1956    0.000104
# 1958    0.000083
# 1937    0.000083
# 1962    0.000083
# 1950    0.000062
# 1954    0.000042
# 1941    0.000042
# 1934    0.000042
# 1957    0.000042
# 1951    0.000042
# 1955    0.000042
# ...

# %% [markdown]
# - frequencies increased for all remaining values because the there are less values involved
# - most values are 1985 and above

# %% [markdown]
# ## Part VII - Exploring Price by Brand

# %%
all_brands=autos['brand'].value_counts(normalize=True)[:20]
print(all_brands)
print(all_brands.shape[0])
print(all_brands.sum())
print(all_brands.index)
# Out:
# volkswagen        0.212126
# bmw               0.110019
# opel              0.108166
# mercedes_benz     0.095361
# audi              0.086387
# ford              0.069793
# renault           0.047347
# peugeot           0.029524
# fiat              0.025860
# seat              0.018177
# skoda             0.016032
# mazda             0.015137
# nissan            0.015095
# citroen           0.013929
# smart             0.013909
# toyota            0.012472
# sonstige_autos    0.010952
# hyundai           0.009848
# volvo             0.009245
# mini              0.008641
# Name: brand, dtype: float64
# 20
# 0.9280211543266427
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat', 'skoda', 'mazda', 'nissan', 'citroen',
#        'smart', 'toyota', 'sonstige_autos', 'hyundai', 'volvo', 'mini'],
#       dtype='object')

# %%
above_this=autos['brand'].value_counts(normalize=True)
above_this=above_this[above_this>0.05]
print(above_this)
print(above_this.shape[0])
print(above_this.sum())
print(above_this.index)
# Out:
# volkswagen       0.212126
# bmw              0.110019
# opel             0.108166
# mercedes_benz    0.095361
# audi             0.086387
# ford             0.069793
# Name: brand, dtype: float64
# 6
# 0.6818522528525027
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %% [markdown]
# - The brands that make up the top 20 brands come from a varieties of countries and classes
# - The top 20 brands make up almost 93% of the brands while the top 5 make up about 68% of the brands. Because the top 20 covers a significantly higher percentage of the listings

# %%
aggdat={}
for brand in all_brands.index:
    bmean=autos['price'][autos['brand'] == brand].mean()
    aggdat[brand]=bmean
print(aggdat)
#sort dictionary by values https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
# Out:
# {'mini': 10460.012048192772, 'nissan': 4664.891034482758, 'seat': 4296.492554410081, 'mazda': 4010.7716643741405, 'mercedes_benz': 30317.447816593885, 'ford': 7263.015811455847, 'fiat': 2711.8011272141707, 'citroen': 44534.79671150971, 'hyundai': 5308.53911205074, 'renault': 2395.4164467897976, 'smart': 3542.706586826347, 'peugeot': 3039.4682651622, 'audi': 9093.65003615329, 'bmw': 8334.645155185466, 'skoda': 6334.91948051948, 'volkswagen': 6516.457597173145, 'toyota': 5115.33388981636, 'volvo': 4757.108108108108, 'sonstige_autos': 39621.77946768061, 'opel': 5252.61655437921}

# %% [markdown]
# - Most brand are within a range of \$2,000 to \$10,000 while others are more expensive and around \$30,000 - \$40,000

# %% [markdown]
# ## Part VIII - Storing Aggregate Data in a DataFrame

# %%
miledat={}
for brand in all_brands.index:
    mmean=autos['odometer_km'][autos['brand'] == brand].mean()
    miledat[brand]=mmean
print(miledat)
# Out:
# {'mini': 88602.40963855422, 'nissan': 118572.41379310345, 'seat': 121563.57388316152, 'mazda': 124745.5295735901, 'mercedes_benz': 130860.26200873363, 'ford': 124046.83770883054, 'fiat': 116553.94524959743, 'citroen': 119461.88340807175, 'hyundai': 106511.62790697675, 'renault': 128183.81706244503, 'smart': 99595.80838323354, 'peugeot': 127136.81241184767, 'audi': 129287.78018799711, 'bmw': 132434.70855412565, 'skoda': 110954.54545454546, 'volkswagen': 128730.36906164115, 'toyota': 115709.51585976628, 'volvo': 138355.85585585586, 'sonstige_autos': 87262.35741444866, 'opel': 129227.14148219442}

# %%
pd_aggdat=pd.Series(aggdat)
pd_miledat=pd.Series(miledat)
df_dat=pd.DataFrame(pd_aggdat, columns=['mean_price'])
df_dat['mean_milage']=pd_miledat
df_dat
# Out:
#                   mean_price    mean_milage
# audi             9093.650036  129287.780188
# bmw              8334.645155  132434.708554
# citroen         44534.796712  119461.883408
# fiat             2711.801127  116553.945250
# ford             7263.015811  124046.837709
# hyundai          5308.539112  106511.627907
# mazda            4010.771664  124745.529574
# mercedes_benz   30317.447817  130860.262009
# mini            10460.012048   88602.409639
# nissan           4664.891034  118572.413793
# opel             5252.616554  129227.141482
# peugeot          3039.468265  127136.812412
# renault          2395.416447  128183.817062
# seat             4296.492554  121563.573883
# skoda            6334.919481  110954.545455
# smart            3542.706587   99595.808383
# sonstige_autos  39621.779468   87262.357414
# toyota           5115.333890  115709.515860
# volkswagen       6516.457597  128730.369062
# volvo            4757.108108  138355.855856

# %%
df_dat.describe()
# Out:
#          mean_price    mean_milage
# count     20.000000      20.000000
# mean   10378.593473  118889.859745
# std    12377.297192   14071.228575
# min     2395.416447   87262.357414
# 25%     4225.062332  114520.773258
# 50%     5280.577833  122805.205796
# 75%     8524.396375  128854.562167
# max    44534.796712  138355.855856

# %%
df_dat.sort_values(by='mean_price')
# Out:
#                   mean_price    mean_milage
# renault          2395.416447  128183.817062
# fiat             2711.801127  116553.945250
# peugeot          3039.468265  127136.812412
# smart            3542.706587   99595.808383
# mazda            4010.771664  124745.529574
# seat             4296.492554  121563.573883
# nissan           4664.891034  118572.413793
# volvo            4757.108108  138355.855856
# toyota           5115.333890  115709.515860
# opel             5252.616554  129227.141482
# hyundai          5308.539112  106511.627907
# skoda            6334.919481  110954.545455
# volkswagen       6516.457597  128730.369062
# ford             7263.015811  124046.837709
# bmw              8334.645155  132434.708554
# audi             9093.650036  129287.780188
# mini            10460.012048   88602.409639
# mercedes_benz   30317.447817  130860.262009
# sonstige_autos  39621.779468   87262.357414
# citroen         44534.796712  119461.883408

# %%
df_dat.sort_values(by='mean_milage')
# Out:
#                   mean_price    mean_milage
# sonstige_autos  39621.779468   87262.357414
# mini            10460.012048   88602.409639
# smart            3542.706587   99595.808383
# hyundai          5308.539112  106511.627907
# skoda            6334.919481  110954.545455
# toyota           5115.333890  115709.515860
# fiat             2711.801127  116553.945250
# nissan           4664.891034  118572.413793
# citroen         44534.796712  119461.883408
# seat             4296.492554  121563.573883
# ford             7263.015811  124046.837709
# mazda            4010.771664  124745.529574
# peugeot          3039.468265  127136.812412
# renault          2395.416447  128183.817062
# volkswagen       6516.457597  128730.369062
# opel             5252.616554  129227.141482
# audi             9093.650036  129287.780188
# mercedes_benz   30317.447817  130860.262009
# bmw              8334.645155  132434.708554
# volvo            4757.108108  138355.855856

# %% [markdown]
# - After sorting values by both mean price and mean milage it is safe to say that amongst the top 20 most popular brands there is weak correlation between the mean price and mean milage
